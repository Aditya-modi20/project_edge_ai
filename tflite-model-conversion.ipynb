# %%
import tensorflow as tf

# Load the Keras model from the .h5 file
model = tf.keras.models.load_model('/kaggle/input/models/adityamodi20/emotion-model/keras/default/1/emotion_model(2).h5')

# Convert the model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the converted model to a .tflite file
with open('model.tflite', 'wb') as f:
    f.write(tflite_model)

print("Conversion complete! The model is saved as 'model.tflite'.")
# Out:
# 2026-02-19 16:27:58.620514: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771518478.875012      47 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771518478.947567      47 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# 2026-02-19 16:28:18.562127: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /tmp/tmpcayacvll/assets
# INFO:tensorflow:Assets written to: /tmp/tmpcayacvll/assets
# Saved artifact at '/tmp/tmpcayacvll'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 200, 200, 1), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   140580424069584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140580424072848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140580424072272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140580424071696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140580423174672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140580423175440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140580423174864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140580423173904: TensorSpec(shape=(), dtype=tf.resource, name=None)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1771518501.060363      47 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1771518501.060441      47 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1771518501.067843      47 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# Conversion complete! The model is saved as 'model.tflite'.

# %%
import tensorflow as tf

# Load the Keras model from the .h5 file
model = tf.keras.models.load_model('/kaggle/input/models/adityamodi20/gender-model/keras/default/1/gender_model(1).h5')

# Convert the model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the converted model to a .tflite file
with open('model.tflite', 'wb') as f:
    f.write(tflite_model)

print("Conversion complete! The model is saved as 'model.tflite'.")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /tmp/tmpvmpw2gmw/assets
# INFO:tensorflow:Assets written to: /tmp/tmpvmpw2gmw/assets
# Saved artifact at '/tmp/tmpvmpw2gmw'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 100, 100, 1), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   140580423186384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140580423185424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140580423185616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140580423185040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140580423185808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140580423184080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140580423184656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140580423187920: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1771518938.585354      47 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1771518938.585391      47 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# Conversion complete! The model is saved as 'model.tflite'.

# %%
import tensorflow as tf

# Load the Keras model from the .h5 file
model = tf.keras.models.load_model('/kaggle/input/models/adityamodi20/age-model2/pytorch/default/1/age-model.h5')

# Convert the model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the converted model to a .tflite file
with open('model.tflite', 'wb') as f:
    f.write(tflite_model)

print("Conversion complete! The model is saved as 'model.tflite'.")
# Out:
# 2026-02-23 16:56:40.868449: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771865801.187457      47 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771865801.273297      47 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# 2026-02-23 16:57:01.329517: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /tmp/tmpg9sutkgt/assets
# INFO:tensorflow:Assets written to: /tmp/tmpg9sutkgt/assets
# Saved artifact at '/tmp/tmpg9sutkgt'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 200, 200, 1), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 21), dtype=tf.float32, name=None)
# Captures:
#   139042917495248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139042917498512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139042913879248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139042913878480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139042913880208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139042913881360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139042913881936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139042913883856: TensorSpec(shape=(), dtype=tf.resource, name=None)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1771865823.115872      47 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1771865823.115949      47 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1771865823.125902      47 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# Conversion complete! The model is saved as 'model.tflite'.
